# %%
import sys, os, csv
import django
sys.path.append('/home/bunny/Desktop/codingtask')

os.environ['DJANGO_SETTINGS_MODULE'] = 'codingtask.settings'

django.setup()
from search.models import *

# %%
path = (os.path.abspath(os.path.join('..', 'restaurants_small.csv')))
modelpath = (os.path.abspath(os.path.join('.', 'models.py')))

df = pd.read_csv(path)

# %%
import json
# df
food_items_list = df.loc[:,"items"]
food_items = json.loads(food_items_list[0])
# lat_long = df.lat_long
full_detail = df.full_details
detail = json.loads(full_detail[0])
# detail

# # Location
Location(
    city = detail['location']['city'],
    address = detail['location']['address'],
    city_id = detail['location']['city_id'],
    zipcode = detail['location']['zipcode'],
    locality = detail['location']['locality'],
    latitude = detail['location']['latitude'],
    longitude = detail['location']['longitude'],
    country_id = detail['location']['country_id']
).save()
# print(city) 
# print(address) 
# print(city_id) 
# print(zipcode) 
# print(locality) 
# print(latitude) 
# print(longitude) 
# print(country_id)

# # Offer
# name = ""

# # Cuisine get_or_create 
# name =  for i in detail['cuisines']

# # Currency get_or_create
# name = for i in detail['currency']

# print(items)
# # FoodItem
# for key in food_items:
#     name = key
#     price = food_items[key]
#     offer = "MTOM"
#     location = "MTOM"
#     print(key)
#     print(food_items[key])


# # Rating
# print(detail['user_rating'])
votes = detail['user_rating']['votes']
rating_text = detail['user_rating']['rating_text']
rating_color = detail['user_rating']['rating_color']
aggregate_rating = detail['user_rating']['aggregate_rating']
food_item = "ForeignKey"
# print(votes)
# print(rating_text)
# print(rating_color)
# print(aggregate_rating)


# # RDetail
name = detail['name']
offers = 'FK'
cuisines = 'MTOM'
currency = 'FK'
rating = 'OTOO'
price_range = detail['price_range']
items = 'FK'
location = 'FK'
mezzo_provider = detail['mezzo_provider']
order_deeplink = detail['order_deeplink']
has_table_booking = detail['has_table_booking']
is_delivering_now = detail['is_delivering_now']
opentable_support = detail['opentable_support']
has_online_delivery = detail['has_online_delivery']
include_bogo_offers = detail['include_bogo_offers']
average_cost_for_two = detail['average_cost_for_two']
switch_to_order_menu = detail['switch_to_order_menu']
is_book_form_web_view = detail['is_book_form_web_view']
book_form_web_view_url = detail['book_form_web_view_url']
is_table_reservation_supported = detail['is_table_reservation_supported']

# print(name)
# print(offers)
# print(cuisines)
# print(currency)
# print(rating)
# print(price_range)
# print(items)
# print(location)
# print(mezzo_provider)
# print(order_deeplink)
# print(has_table_booking)
# print(is_delivering_now)
# print(opentable_support)
# print(has_online_delivery)
# print(include_bogo_offers)
# print(average_cost_for_two)
# print(switch_to_order_menu)
# print(is_book_form_web_view)
# print(book_form_web_view_url)
# print(is_table_reservation_supported)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[138], line 11
#       7 detail = json.loads(full_detail[0])
#       8 # detail
#       9
#      10 # # Location
# ---> 11 Location(
#      12     city = detail['location']['city'],
#      13     address = detail['location']['address'],
#      14     city_id = detail['location']['city_id'],
#      15     zipcode = detail['location']['zipcode'],
#      16     locality = detail['location']['locality'],
#      17     latitude = detail['location']['latitude'],
#      18     longitude = detail['location']['longitude'],
#      19     country_id = detail['location']['country_id']
#      20 ).save()
#      21 # print(city)
#      22 # print(address)
#      23 # print(city_id)
#    (...)
#      50 # # Rating
#      51 # print(detail['user_rating'])
#      52 votes = detail['user_rating']['votes']
#
# File ~/.local/lib/python3.10/site-packages/django/db/models/base.py:567, in Model.__init__(self, *args, **kwargs)
#     565     if unexpected:
#     566         unexpected_names = ", ".join(repr(n) for n in unexpected)
# --> 567         raise TypeError(
#     568             f"{cls.__name__}() got unexpected keyword arguments: "
#     569             f"{unexpected_names}"
#     570         )
#     571 super().__init__()
#     572 post_init.send(sender=cls, instance=self)
#
# TypeError: Location() got unexpected keyword arguments: 'city', 'address', 'city_id', 'zipcode', 'country_id'
